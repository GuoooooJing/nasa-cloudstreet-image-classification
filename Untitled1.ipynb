# %%
import torch
from PIL import Image
import os

# %%
NO_PATH = "./cloudstreet/no/"
YES_PATH = "./cloudstreet/yes/"
TRAIN_NO_PATH = "./dataset/train/0/"
TRAIN_YES_PATH = "./dataset/train/1/"
TEST_NO_PATH = "./dataset/test/0/"
TEST_YES_PATH = "./dataset/test/1/"
train_no_num = 200
train_yes_num = 400
test_no_num = 100
test_yes_num = 200

# %%
lst_no = os.listdir(NO_PATH)
lst_yes = os.listdir(YES_PATH)

# %%
import random
datalst_no = random.sample(lst_no, k=(train_no_num+test_no_num))
datalst_yes = random.sample(lst_yes, k=(train_yes_num+test_yes_num))

# %%
for i in os.listdir(TRAIN_NO_PATH):
    try:
        os.remove(TRAIN_NO_PATH+i)
    except OSError as e:
        print("Error: %s : %s" % (TRAIN_NO_PATH+i, e.strerror))
        
for i in os.listdir(TRAIN_YES_PATH):
    try:
        os.remove(TRAIN_YES_PATH+i)
    except OSError as e:
        print("Error: %s : %s" % (TRAIN_YES_PATH+i, e.strerror))
        
for i in os.listdir(TEST_NO_PATH):
    try:
        os.remove(TEST_NO_PATH+i)
    except OSError as e:
        print("Error: %s : %s" % (TEST_NO_PATH+i, e.strerror))
        
for i in os.listdir(TEST_YES_PATH):
    try:
        os.remove(TEST_YES_PATH+i)
    except OSError as e:
        print("Error: %s : %s" % (TEST_YES_PATH+i, e.strerror))

# %%
for i, n in enumerate(datalst_no):
    img = Image.open(NO_PATH+n).resize((800,800))
    if i < train_no_num:
        img.save(TRAIN_NO_PATH+n)
    else:
        img.save(TEST_NO_PATH+n)
    
for i, n in enumerate(datalst_yes):
    img = Image.open(YES_PATH+n).resize((800,800))
    if i < train_yes_num:
        img.save(TRAIN_YES_PATH+n)
    else:
        img.save(TEST_YES_PATH+n)

# %%
print(len(os.listdir(TEST_NO_PATH)), len(os.listdir(TEST_YES_PATH)), len(os.listdir(TRAIN_NO_PATH)), len(os.listdir(TRAIN_YES_PATH)))
# Out:
# 100 187 200 383

# %%
import torch 
import torch.nn as nn
import torchvision
import torchvision.transforms as transforms
import csv

# %%
# Device configuration
device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

# Hyper parameters
num_epochs = 40
num_classes = 2
batch_size = 64
learning_rate = 0.01

# MNIST dataset

train_dataset = torchvision.datasets.ImageFolder(root='./dataset/train/',
                                           transform=transforms.ToTensor())

test_dataset = torchvision.datasets.ImageFolder(root='./dataset/test/',
                                          transform=transforms.ToTensor())

# Data loader
train_loader = torch.utils.data.DataLoader(dataset=train_dataset,
                                           batch_size=batch_size, 
                                           shuffle=True)

test_loader = torch.utils.data.DataLoader(dataset=test_dataset,
                                          batch_size=batch_size, 
                                          shuffle=False)

# %%
len(train_loader)
# Out:
# 10

# %%
# Convolutional neural network (two convolutional layers)
class ConvNet(nn.Module):
    def __init__(self, num_classes=10):
        super(ConvNet, self).__init__()
        self.layer1 = nn.Sequential(
            nn.Conv2d(3, 16, kernel_size=6, stride=2, padding=3),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.layer2 = nn.Sequential(
            nn.Conv2d(16, 32, kernel_size=5, stride=1, padding=4),
            nn.BatchNorm2d(32),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.layer3 = nn.Sequential(
            nn.Conv2d(32, 64, kernel_size=5, stride=1, padding=2),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.fc1 = nn.Linear(51*51*64, 64)
        self.fc2 = nn.Linear(64, 2)
        self.fc3 = nn.Sigmoid()
        self.relu = nn.ReLU()
        self.dropout = nn.Dropout(0.1)

    def forward(self, x):
        out = self.layer1(x)
        out = self.layer2(out)
        out = self.layer3(out)
        #print(out.size())
        out = out.reshape(out.size(0), -1)
        out = self.relu(self.fc1(out))
        out = self.dropout(out)
        out = self.fc2(out)
        out = self.fc3(out)
        return out

# %%
if 'loss.csv' in os.listdir('./'):
    os.remove('loss.csv')

model = ConvNet(num_classes).to(device)

# Loss and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

# Train the model
total_step = len(train_loader)
for epoch in range(num_epochs):
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)
        
        # Forward pass
        outputs = model(images)
        loss = criterion(outputs, labels)
        
        # Backward and optimize
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        print ('Epoch [{}/{}], Step [{}/{}], Loss: {:.4f}' 
                   .format(epoch+1, num_epochs, i+1, total_step, loss.item()))
        with open(r'loss.csv', 'a') as f:
            writer = csv.writer(f)
            writer.writerow([loss.item()])
    torch.save(model.state_dict(), 'model.ckpt')

# Test the model

model.eval()  # eval mode (batchnorm uses moving mean/variance instead of mini-batch mean/variance)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Test Accuracy of the model on the 10000 test images: {} %'.format(100 * correct / total))

# Save the model checkpoint
# torch.save(model.state_dict(), 'model.ckpt')
# Out:
# Epoch [1/40], Step [1/10], Loss: 0.6994
# Epoch [1/40], Step [2/10], Loss: 0.6414
# Epoch [1/40], Step [3/10], Loss: 0.6101
# Epoch [1/40], Step [4/10], Loss: 0.6726
# Epoch [1/40], Step [5/10], Loss: 0.7039
# Epoch [1/40], Step [6/10], Loss: 0.5789
# Epoch [1/40], Step [7/10], Loss: 0.6101
# Epoch [1/40], Step [8/10], Loss: 0.7195
# Epoch [1/40], Step [9/10], Loss: 0.7039
# Epoch [1/40], Step [10/10], Loss: 0.8133
# Epoch [2/40], Step [1/10], Loss: 0.6726
# Epoch [2/40], Step [2/10], Loss: 0.6726
# Epoch [2/40], Step [3/10], Loss: 0.5945
# Epoch [2/40], Step [4/10], Loss: 0.6414
# Epoch [2/40], Step [5/10], Loss: 0.6883
# Epoch [2/40], Step [6/10], Loss: 0.6101
# Epoch [2/40], Step [7/10], Loss: 0.6883
# Epoch [2/40], Step [8/10], Loss: 0.7508
# Epoch [2/40], Step [9/10], Loss: 0.5789
# Epoch [2/40], Step [10/10], Loss: 0.8133
# Epoch [3/40], Step [1/10], Loss: 0.7351
# Epoch [3/40], Step [2/10], Loss: 0.5476
# Epoch [3/40], Step [3/10], Loss: 0.7039
# Epoch [3/40], Step [4/10], Loss: 0.6570
# Epoch [3/40], Step [5/10], Loss: 0.7039
# Epoch [3/40], Step [6/10], Loss: 0.5789
# Epoch [3/40], Step [7/10], Loss: 0.6414
# Epoch [3/40], Step [8/10], Loss: 0.6414
# Epoch [3/40], Step [9/10], Loss: 0.6726
# Epoch [3/40], Step [10/10], Loss: 0.9799
# Epoch [4/40], Step [1/10], Loss: 0.6414
# Epoch [4/40], Step [2/10], Loss: 0.6414
# Epoch [4/40], Step [3/10], Loss: 0.5633
# Epoch [4/40], Step [4/10], Loss: 0.6883
# Epoch [4/40], Step [5/10], Loss: 0.6414
# Epoch [4/40], Step [6/10], Loss: 0.6883
# Epoch [4/40], Step [7/10], Loss: 0.6726
# Epoch [4/40], Step [8/10], Loss: 0.7039
# Epoch [4/40], Step [9/10], Loss: 0.6726
# Epoch [4/40], Step [10/10], Loss: 0.6466
# Epoch [5/40], Step [1/10], Loss: 0.7039
# Epoch [5/40], Step [2/10], Loss: 0.5320
# Epoch [5/40], Step [3/10], Loss: 0.6570
# Epoch [5/40], Step [4/10], Loss: 0.7820
# Epoch [5/40], Step [5/10], Loss: 0.6101
# Epoch [5/40], Step [6/10], Loss: 0.7195
# Epoch [5/40], Step [7/10], Loss: 0.6570
# Epoch [5/40], Step [8/10], Loss: 0.6414
# Epoch [5/40], Step [9/10], Loss: 0.5945
# Epoch [5/40], Step [10/10], Loss: 0.8133
# Epoch [6/40], Step [1/10], Loss: 0.7351
# Epoch [6/40], Step [2/10], Loss: 0.6414
# Epoch [6/40], Step [3/10], Loss: 0.6258
# Epoch [6/40], Step [4/10], Loss: 0.6258
# Epoch [6/40], Step [5/10], Loss: 0.5945
# Epoch [6/40], Step [6/10], Loss: 0.7195
# Epoch [6/40], Step [7/10], Loss: 0.6101
# Epoch [6/40], Step [8/10], Loss: 0.6414
# Epoch [6/40], Step [9/10], Loss: 0.7351
# Epoch [6/40], Step [10/10], Loss: 0.4799
# Epoch [7/40], Step [1/10], Loss: 0.6414
# Epoch [7/40], Step [2/10], Loss: 0.6101
# Epoch [7/40], Step [3/10], Loss: 0.7976
# Epoch [7/40], Step [4/10], Loss: 0.5789
# Epoch [7/40], Step [5/10], Loss: 0.6258
# Epoch [7/40], Step [6/10], Loss: 0.6258
# Epoch [7/40], Step [7/10], Loss: 0.7351
# Epoch [7/40], Step [8/10], Loss: 0.7039
# Epoch [7/40], Step [9/10], Loss: 0.5789
# Epoch [7/40], Step [10/10], Loss: 0.8133
# Epoch [8/40], Step [1/10], Loss: 0.6258
# Epoch [8/40], Step [2/10], Loss: 0.6258
# Epoch [8/40], Step [3/10], Loss: 0.6101
# Epoch [8/40], Step [4/10], Loss: 0.7039
# Epoch [8/40], Step [5/10], Loss: 0.6883
# Epoch [8/40], Step [6/10], Loss: 0.5945
# Epoch [8/40], Step [7/10], Loss: 0.7039
# Epoch [8/40], Step [8/10], Loss: 0.6570
# Epoch [8/40], Step [9/10], Loss: 0.7039
# Epoch [8/40], Step [10/10], Loss: 0.6466
# Epoch [9/40], Step [1/10], Loss: 0.6883
# Epoch [9/40], Step [2/10], Loss: 0.6570
# Epoch [9/40], Step [3/10], Loss: 0.6414
# Epoch [9/40], Step [4/10], Loss: 0.6726
# Epoch [9/40], Step [5/10], Loss: 0.6101
# Epoch [9/40], Step [6/10], Loss: 0.6726
# Epoch [9/40], Step [7/10], Loss: 0.7039
# Epoch [9/40], Step [8/10], Loss: 0.6883
# Epoch [9/40], Step [9/10], Loss: 0.5945
# Epoch [9/40], Step [10/10], Loss: 0.4799
# Epoch [10/40], Step [1/10], Loss: 0.5789
# Epoch [10/40], Step [2/10], Loss: 0.6414
# Epoch [10/40], Step [3/10], Loss: 0.5945
# Epoch [10/40], Step [4/10], Loss: 0.6726
# Epoch [10/40], Step [5/10], Loss: 0.6258
# Epoch [10/40], Step [6/10], Loss: 0.6726
# Epoch [10/40], Step [7/10], Loss: 0.6414
# Epoch [10/40], Step [8/10], Loss: 0.7664
# Epoch [10/40], Step [9/10], Loss: 0.7039
# Epoch [10/40], Step [10/10], Loss: 0.8133
# Epoch [11/40], Step [1/10], Loss: 0.6726
# Epoch [11/40], Step [2/10], Loss: 0.6570
# Epoch [11/40], Step [3/10], Loss: 0.6726
# Epoch [11/40], Step [4/10], Loss: 0.6101
# Epoch [11/40], Step [5/10], Loss: 0.5633
# Epoch [11/40], Step [6/10], Loss: 0.6570
# Epoch [11/40], Step [7/10], Loss: 0.6414
# Epoch [11/40], Step [8/10], Loss: 0.6258
# Epoch [11/40], Step [9/10], Loss: 0.8133
# Epoch [11/40], Step [10/10], Loss: 0.6466
# Epoch [12/40], Step [1/10], Loss: 0.7039
# Epoch [12/40], Step [2/10], Loss: 0.6258
# Epoch [12/40], Step [3/10], Loss: 0.6414
# Epoch [12/40], Step [4/10], Loss: 0.6570
# Epoch [12/40], Step [5/10], Loss: 0.6726
# Epoch [12/40], Step [6/10], Loss: 0.6258
# Epoch [12/40], Step [7/10], Loss: 0.6101
# Epoch [12/40], Step [8/10], Loss: 0.6570
# Epoch [12/40], Step [9/10], Loss: 0.7351
# Epoch [12/40], Step [10/10], Loss: 0.4799
# Epoch [13/40], Step [1/10], Loss: 0.5789
# Epoch [13/40], Step [2/10], Loss: 0.6101
# Epoch [13/40], Step [3/10], Loss: 0.5945
# Epoch [13/40], Step [4/10], Loss: 0.6883
# Epoch [13/40], Step [5/10], Loss: 0.7039
# Epoch [13/40], Step [6/10], Loss: 0.7351
# Epoch [13/40], Step [7/10], Loss: 0.7195
# Epoch [13/40], Step [8/10], Loss: 0.6101
# Epoch [13/40], Step [9/10], Loss: 0.6726
# Epoch [13/40], Step [10/10], Loss: 0.6466
# Epoch [14/40], Step [1/10], Loss: 0.6883
# Epoch [14/40], Step [2/10], Loss: 0.6883
# Epoch [14/40], Step [3/10], Loss: 0.6570
# Epoch [14/40], Step [4/10], Loss: 0.6726
# Epoch [14/40], Step [5/10], Loss: 0.6726
# Epoch [14/40], Step [6/10], Loss: 0.7039
# Epoch [14/40], Step [7/10], Loss: 0.6258
# Epoch [14/40], Step [8/10], Loss: 0.5789
# Epoch [14/40], Step [9/10], Loss: 0.6258
# Epoch [14/40], Step [10/10], Loss: 0.6466
# Epoch [15/40], Step [1/10], Loss: 0.6101
# Epoch [15/40], Step [2/10], Loss: 0.6726
# Epoch [15/40], Step [3/10], Loss: 0.6101
# Epoch [15/40], Step [4/10], Loss: 0.7195
# Epoch [15/40], Step [5/10], Loss: 0.5945
# Epoch [15/40], Step [6/10], Loss: 0.6570
# Epoch [15/40], Step [7/10], Loss: 0.6726
# Epoch [15/40], Step [8/10], Loss: 0.6258
# Epoch [15/40], Step [9/10], Loss: 0.7664
# Epoch [15/40], Step [10/10], Loss: 0.4799
# Epoch [16/40], Step [1/10], Loss: 0.7039
# Epoch [16/40], Step [2/10], Loss: 0.6726
# Epoch [16/40], Step [3/10], Loss: 0.7039
# Epoch [16/40], Step [4/10], Loss: 0.6570
# Epoch [16/40], Step [5/10], Loss: 0.5789
# Epoch [16/40], Step [6/10], Loss: 0.6258
# Epoch [16/40], Step [7/10], Loss: 0.6101
# Epoch [16/40], Step [8/10], Loss: 0.5633
# Epoch [16/40], Step [9/10], Loss: 0.8133
# Epoch [16/40], Step [10/10], Loss: 0.4799
# Epoch [17/40], Step [1/10], Loss: 0.6258
# Epoch [17/40], Step [2/10], Loss: 0.6726
# Epoch [17/40], Step [3/10], Loss: 0.6570
# Epoch [17/40], Step [4/10], Loss: 0.5789
# Epoch [17/40], Step [5/10], Loss: 0.6101
# Epoch [17/40], Step [6/10], Loss: 0.6726
# Epoch [17/40], Step [7/10], Loss: 0.7820
# Epoch [17/40], Step [8/10], Loss: 0.6570
# Epoch [17/40], Step [9/10], Loss: 0.6883
# Epoch [17/40], Step [10/10], Loss: 0.3133
# Epoch [18/40], Step [1/10], Loss: 0.7195
# Epoch [18/40], Step [2/10], Loss: 0.6414
# Epoch [18/40], Step [3/10], Loss: 0.6414
# Epoch [18/40], Step [4/10], Loss: 0.5945
# Epoch [18/40], Step [5/10], Loss: 0.6726
# Epoch [18/40], Step [6/10], Loss: 0.6883
# Epoch [18/40], Step [7/10], Loss: 0.6883
# Epoch [18/40], Step [8/10], Loss: 0.6726
# Epoch [18/40], Step [9/10], Loss: 0.5633
# Epoch [18/40], Step [10/10], Loss: 0.9799
# Epoch [19/40], Step [1/10], Loss: 0.6101
# Epoch [19/40], Step [2/10], Loss: 0.5789
# Epoch [19/40], Step [3/10], Loss: 0.7039
# Epoch [19/40], Step [4/10], Loss: 0.5945
# Epoch [19/40], Step [5/10], Loss: 0.7664
# Epoch [19/40], Step [6/10], Loss: 0.5945
# Epoch [19/40], Step [7/10], Loss: 0.7820
# Epoch [19/40], Step [8/10], Loss: 0.6726
# Epoch [19/40], Step [9/10], Loss: 0.6258
# Epoch [19/40], Step [10/10], Loss: 0.4799
# Epoch [20/40], Step [1/10], Loss: 0.7039
# Epoch [20/40], Step [2/10], Loss: 0.6883
# Epoch [20/40], Step [3/10], Loss: 0.5008
# Epoch [20/40], Step [4/10], Loss: 0.6726
# Epoch [20/40], Step [5/10], Loss: 0.6883
# Epoch [20/40], Step [6/10], Loss: 0.6258
# Epoch [20/40], Step [7/10], Loss: 0.6101
# Epoch [20/40], Step [8/10], Loss: 0.7195
# Epoch [20/40], Step [9/10], Loss: 0.7195
# Epoch [20/40], Step [10/10], Loss: 0.4799
# Epoch [21/40], Step [1/10], Loss: 0.6726
# Epoch [21/40], Step [2/10], Loss: 0.5633
# Epoch [21/40], Step [3/10], Loss: 0.6570
# Epoch [21/40], Step [4/10], Loss: 0.6414
# Epoch [21/40], Step [5/10], Loss: 0.7195
# Epoch [21/40], Step [6/10], Loss: 0.6570
# Epoch [21/40], Step [7/10], Loss: 0.7195
# Epoch [21/40], Step [8/10], Loss: 0.7039
# Epoch [21/40], Step [9/10], Loss: 0.5789
# Epoch [21/40], Step [10/10], Loss: 0.6466
# Epoch [22/40], Step [1/10], Loss: 0.6414
# Epoch [22/40], Step [2/10], Loss: 0.5789
# Epoch [22/40], Step [3/10], Loss: 0.6414
# Epoch [22/40], Step [4/10], Loss: 0.7195
# Epoch [22/40], Step [5/10], Loss: 0.6414
# Epoch [22/40], Step [6/10], Loss: 0.7195
# Epoch [22/40], Step [7/10], Loss: 0.7664
# Epoch [22/40], Step [8/10], Loss: 0.6258
# Epoch [22/40], Step [9/10], Loss: 0.5945
# Epoch [22/40], Step [10/10], Loss: 0.4799
# Epoch [23/40], Step [1/10], Loss: 0.6726
# Epoch [23/40], Step [2/10], Loss: 0.5633
# Epoch [23/40], Step [3/10], Loss: 0.6414
# Epoch [23/40], Step [4/10], Loss: 0.6726
# Epoch [23/40], Step [5/10], Loss: 0.7195
# Epoch [23/40], Step [6/10], Loss: 0.7351
# Epoch [23/40], Step [7/10], Loss: 0.6414
# Epoch [23/40], Step [8/10], Loss: 0.6258
# Epoch [23/40], Step [9/10], Loss: 0.6258
# Epoch [23/40], Step [10/10], Loss: 0.8133
# Epoch [24/40], Step [1/10], Loss: 0.6258
# Epoch [24/40], Step [2/10], Loss: 0.6414
# Epoch [24/40], Step [3/10], Loss: 0.7351
# Epoch [24/40], Step [4/10], Loss: 0.6101
# Epoch [24/40], Step [5/10], Loss: 0.6101
# Epoch [24/40], Step [6/10], Loss: 0.6258
# Epoch [24/40], Step [7/10], Loss: 0.7664
# Epoch [24/40], Step [8/10], Loss: 0.6570
# Epoch [24/40], Step [9/10], Loss: 0.6570
# Epoch [24/40], Step [10/10], Loss: 0.4799
# Epoch [25/40], Step [1/10], Loss: 0.6101
# Epoch [25/40], Step [2/10], Loss: 0.5789
# Epoch [25/40], Step [3/10], Loss: 0.7195
# Epoch [25/40], Step [4/10], Loss: 0.7351
# Epoch [25/40], Step [5/10], Loss: 0.6883
# Epoch [25/40], Step [6/10], Loss: 0.5789
# Epoch [25/40], Step [7/10], Loss: 0.6883
# Epoch [25/40], Step [8/10], Loss: 0.6726
# Epoch [25/40], Step [9/10], Loss: 0.6570
# Epoch [25/40], Step [10/10], Loss: 0.4799
# Epoch [26/40], Step [1/10], Loss: 0.6726
# Epoch [26/40], Step [2/10], Loss: 0.7195
# Epoch [26/40], Step [3/10], Loss: 0.5476
# Epoch [26/40], Step [4/10], Loss: 0.6883
# Epoch [26/40], Step [5/10], Loss: 0.6570
# Epoch [26/40], Step [6/10], Loss: 0.6101
# Epoch [26/40], Step [7/10], Loss: 0.7195
# Epoch [26/40], Step [8/10], Loss: 0.6414
# Epoch [26/40], Step [9/10], Loss: 0.6414
# Epoch [26/40], Step [10/10], Loss: 0.8133
# Epoch [27/40], Step [1/10], Loss: 0.6726
# Epoch [27/40], Step [2/10], Loss: 0.6726
# Epoch [27/40], Step [3/10], Loss: 0.6258
# Epoch [27/40], Step [4/10], Loss: 0.7039
# Epoch [27/40], Step [5/10], Loss: 0.7664
# Epoch [27/40], Step [6/10], Loss: 0.6258
# Epoch [27/40], Step [7/10], Loss: 0.6101
# Epoch [27/40], Step [8/10], Loss: 0.6101
# Epoch [27/40], Step [9/10], Loss: 0.6258
# Epoch [27/40], Step [10/10], Loss: 0.6466
# Epoch [28/40], Step [1/10], Loss: 0.7195
# Epoch [28/40], Step [2/10], Loss: 0.7039
# Epoch [28/40], Step [3/10], Loss: 0.6726
# Epoch [28/40], Step [4/10], Loss: 0.5476
# Epoch [28/40], Step [5/10], Loss: 0.6414
# Epoch [28/40], Step [6/10], Loss: 0.6726
# Epoch [28/40], Step [7/10], Loss: 0.5945
# Epoch [28/40], Step [8/10], Loss: 0.6726
# Epoch [28/40], Step [9/10], Loss: 0.6570
# Epoch [28/40], Step [10/10], Loss: 0.9799
# Epoch [29/40], Step [1/10], Loss: 0.6883
# Epoch [29/40], Step [2/10], Loss: 0.5945
# Epoch [29/40], Step [3/10], Loss: 0.5476
# Epoch [29/40], Step [4/10], Loss: 0.6258
# Epoch [29/40], Step [5/10], Loss: 0.6883
# Epoch [29/40], Step [6/10], Loss: 0.6726
# Epoch [29/40], Step [7/10], Loss: 0.6570
# Epoch [29/40], Step [8/10], Loss: 0.7039
# Epoch [29/40], Step [9/10], Loss: 0.7351
# Epoch [29/40], Step [10/10], Loss: 0.6466
# Epoch [30/40], Step [1/10], Loss: 0.5945
# Epoch [30/40], Step [2/10], Loss: 0.6258
# Epoch [30/40], Step [3/10], Loss: 0.7508
# Epoch [30/40], Step [4/10], Loss: 0.7195
# Epoch [30/40], Step [5/10], Loss: 0.6258
# Epoch [30/40], Step [6/10], Loss: 0.6883
# Epoch [30/40], Step [7/10], Loss: 0.5633
# Epoch [30/40], Step [8/10], Loss: 0.6883
# Epoch [30/40], Step [9/10], Loss: 0.6883
# Epoch [30/40], Step [10/10], Loss: 0.3133
# Epoch [31/40], Step [1/10], Loss: 0.6726
# Epoch [31/40], Step [2/10], Loss: 0.6101
# Epoch [31/40], Step [3/10], Loss: 0.6570
# Epoch [31/40], Step [4/10], Loss: 0.5789
# Epoch [31/40], Step [5/10], Loss: 0.6726
# Epoch [31/40], Step [6/10], Loss: 0.7351
# Epoch [31/40], Step [7/10], Loss: 0.6726
# Epoch [31/40], Step [8/10], Loss: 0.6258
# Epoch [31/40], Step [9/10], Loss: 0.6726
# Epoch [31/40], Step [10/10], Loss: 0.8133
# Epoch [32/40], Step [1/10], Loss: 0.5320
# Epoch [32/40], Step [2/10], Loss: 0.7195
# Epoch [32/40], Step [3/10], Loss: 0.6883
# Epoch [32/40], Step [4/10], Loss: 0.6101
# Epoch [32/40], Step [5/10], Loss: 0.6883
# Epoch [32/40], Step [6/10], Loss: 0.5789
# Epoch [32/40], Step [7/10], Loss: 0.6883
# Epoch [32/40], Step [8/10], Loss: 0.6883
# Epoch [32/40], Step [9/10], Loss: 0.7195
# Epoch [32/40], Step [10/10], Loss: 0.6466
# Epoch [33/40], Step [1/10], Loss: 0.6258
# Epoch [33/40], Step [2/10], Loss: 0.6726
# Epoch [33/40], Step [3/10], Loss: 0.6258
# Epoch [33/40], Step [4/10], Loss: 0.6414
# Epoch [33/40], Step [5/10], Loss: 0.6414
# Epoch [33/40], Step [6/10], Loss: 0.7508
# Epoch [33/40], Step [7/10], Loss: 0.6570
# Epoch [33/40], Step [8/10], Loss: 0.6258
# Epoch [33/40], Step [9/10], Loss: 0.6726
# Epoch [33/40], Step [10/10], Loss: 0.6466
# Epoch [34/40], Step [1/10], Loss: 0.6258
# Epoch [34/40], Step [2/10], Loss: 0.5945
# Epoch [34/40], Step [3/10], Loss: 0.6570
# Epoch [34/40], Step [4/10], Loss: 0.6883
# Epoch [34/40], Step [5/10], Loss: 0.7195
# Epoch [34/40], Step [6/10], Loss: 0.6258
# Epoch [34/40], Step [7/10], Loss: 0.6726
# Epoch [34/40], Step [8/10], Loss: 0.7351
# Epoch [34/40], Step [9/10], Loss: 0.6101
# Epoch [34/40], Step [10/10], Loss: 0.4799
# Epoch [35/40], Step [1/10], Loss: 0.6101
# Epoch [35/40], Step [2/10], Loss: 0.6101
# Epoch [35/40], Step [3/10], Loss: 0.7351
# Epoch [35/40], Step [4/10], Loss: 0.5789
# Epoch [35/40], Step [5/10], Loss: 0.7351
# Epoch [35/40], Step [6/10], Loss: 0.7039
# Epoch [35/40], Step [7/10], Loss: 0.6726
# Epoch [35/40], Step [8/10], Loss: 0.6883
# Epoch [35/40], Step [9/10], Loss: 0.5789
# Epoch [35/40], Step [10/10], Loss: 0.6466
# Epoch [36/40], Step [1/10], Loss: 0.7508
# Epoch [36/40], Step [2/10], Loss: 0.7195
# Epoch [36/40], Step [3/10], Loss: 0.5945
# Epoch [36/40], Step [4/10], Loss: 0.7195
# Epoch [36/40], Step [5/10], Loss: 0.6101
# Epoch [36/40], Step [6/10], Loss: 0.6101
# Epoch [36/40], Step [7/10], Loss: 0.6726
# Epoch [36/40], Step [8/10], Loss: 0.6414
# Epoch [36/40], Step [9/10], Loss: 0.6101
# Epoch [36/40], Step [10/10], Loss: 0.4799
# Epoch [37/40], Step [1/10], Loss: 0.6726
# Epoch [37/40], Step [2/10], Loss: 0.6883
# Epoch [37/40], Step [3/10], Loss: 0.6883
# Epoch [37/40], Step [4/10], Loss: 0.7820
# Epoch [37/40], Step [5/10], Loss: 0.6570
# Epoch [37/40], Step [6/10], Loss: 0.6726
# Epoch [37/40], Step [7/10], Loss: 0.5320
# Epoch [37/40], Step [8/10], Loss: 0.6101
# Epoch [37/40], Step [9/10], Loss: 0.6101
# Epoch [37/40], Step [10/10], Loss: 0.6466
# Epoch [38/40], Step [1/10], Loss: 0.6101
# Epoch [38/40], Step [2/10], Loss: 0.6726
# Epoch [38/40], Step [3/10], Loss: 0.6414
# Epoch [38/40], Step [4/10], Loss: 0.6414
# Epoch [38/40], Step [5/10], Loss: 0.5476
# Epoch [38/40], Step [6/10], Loss: 0.6570
# Epoch [38/40], Step [7/10], Loss: 0.7351
# Epoch [38/40], Step [8/10], Loss: 0.6726
# Epoch [38/40], Step [9/10], Loss: 0.7351
# Epoch [38/40], Step [10/10], Loss: 0.6466
# Epoch [39/40], Step [1/10], Loss: 0.7508
# Epoch [39/40], Step [2/10], Loss: 0.6883
# Epoch [39/40], Step [3/10], Loss: 0.6414
# Epoch [39/40], Step [4/10], Loss: 0.6414
# Epoch [39/40], Step [5/10], Loss: 0.6414
# Epoch [39/40], Step [6/10], Loss: 0.6414
# Epoch [39/40], Step [7/10], Loss: 0.5789
# Epoch [39/40], Step [8/10], Loss: 0.5476
# Epoch [39/40], Step [9/10], Loss: 0.7351
# Epoch [39/40], Step [10/10], Loss: 1.1466
# Epoch [40/40], Step [1/10], Loss: 0.5789
# Epoch [40/40], Step [2/10], Loss: 0.6101
# Epoch [40/40], Step [3/10], Loss: 0.7039
# Epoch [40/40], Step [4/10], Loss: 0.7508
# Epoch [40/40], Step [5/10], Loss: 0.6414
# Epoch [40/40], Step [6/10], Loss: 0.6414
# Epoch [40/40], Step [7/10], Loss: 0.7508
# Epoch [40/40], Step [8/10], Loss: 0.5789
# Epoch [40/40], Step [9/10], Loss: 0.6570
# Epoch [40/40], Step [10/10], Loss: 0.6466
# Test Accuracy of the model on the 10000 test images: 65.03496503496504 %

# %%
model = ConvNet(num_classes)
model.load_state_dict(torch.load('model.ckpt'))
model.eval()  # eval mode (batchnorm uses moving mean/variance instead of mini-batch mean/variance)
with torch.no_grad():
    correct = 0
    total = 0
    for images, labels in test_loader:
        images = images.to(device)
        labels = labels.to(device)
        outputs = model(images)
        print(outputs)
        print("=======================")
        print(labels)
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

    print('Test Accuracy of the model on the 10000 test images: {} %'.format(100 * correct / total))
